# %% [markdown]
# # Prepping the Data
#
# **Description:**
# This notebook prepares all the financial data we get from yfinance.

# %%
#installing yfinance
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /srv/conda/envs/notebook/lib/python3.12/site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (2.3.0)
# Requirement already satisfied: numpy>=1.16.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests>=2.31->yfinance) (1.26.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import sys

#Going to use the scripts folder now cus project said so.
sys.path.append(os.path.abspath(os.path.join("..")))
from scripts.data_process import download_sp500, add_technical_indicators

# %%
#Downloading the Data

sp500 = download_sp500(start_date="1990-01-01")
print(sp500.head())
print(sp500.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close        High         Low        Open     Volume
# Date
# 1990-01-02  359.690002  359.690002  351.980011  353.399994  162070000
# 1990-01-03  358.760010  360.589996  357.890015  359.690002  192330000
# 1990-01-04  355.670013  358.760010  352.890015  358.760010  177000000
# 1990-01-05  352.200012  355.670013  351.350006  355.670013  158530000
# 1990-01-08  353.790009  354.239990  350.540009  352.200012  140110000
#                   Close         High          Low         Open      Volume
# Date
# 2025-12-02  6829.370117  6851.549805  6806.709961  6830.959961  4582290000
# 2025-12-03  6849.720215  6862.419922  6810.430176  6815.290039  4736780000
# 2025-12-04  6857.120117  6866.470215  6827.120117  6866.470215  4872440000
# 2025-12-05  6870.399902  6895.779785  6858.290039  6866.319824  4944560000
# 2025-12-08  6846.509766  6878.270020  6827.189941  6875.200195  3191290000

# %%
# feature engineering data
sp500_feat = add_technical_indicators(sp500)
print(sp500_feat.head())
# Out:
#                  Close        High         Low        Open     Volume  MA10  \
# Date
# 1990-01-02  359.690002  359.690002  351.980011  353.399994  162070000   NaN
# 1990-01-03  358.760010  360.589996  357.890015  359.690002  192330000   NaN
# 1990-01-04  355.670013  358.760010  352.890015  358.760010  177000000   NaN
# 1990-01-05  352.200012  355.670013  351.350006  355.670013  158530000   NaN
# 1990-01-08  353.790009  354.239990  350.540009  352.200012  140110000   NaN
#
#             MA50       EMA10       EMA50    Return  LogReturn  Volatility20  \
# Date
# 1990-01-02   NaN  359.690002  359.690002       NaN        NaN           NaN
# 1990-01-03   NaN  359.520913  359.653532 -0.002586  -0.002589           NaN
# 1990-01-04   NaN  358.820749  359.497316 -0.008613  -0.008650           NaN
# 1990-01-05   NaN  357.616979  359.211147 -0.009756  -0.009804           NaN
# 1990-01-08   NaN  356.921166  358.998553  0.004514   0.004504           NaN
#
#             Momentum10      MACD  MACD_signal
# Date
# 1990-01-02         NaN  0.000000     0.000000
# 1990-01-03         NaN -0.074187    -0.014837
# 1990-01-04         NaN -0.377962    -0.087462
# 1990-01-05         NaN -0.888463    -0.247662
# 1990-01-08         NaN -1.151466    -0.428423

# %%
#saving the data into the data folder because proj wanted us to do that

final_data = "../data/sp500.csv"
sp500_feat.to_csv(final_data)
